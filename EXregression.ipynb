# %% [markdown]
# # **Linear Regression**
#
# Simple Linear Regression finds out the linear relationship
# between single numeric dependent variable and a single
# numeric independent variable

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/Salary_Data.csv")

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = df.iloc[:,:1]
x
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y = df.iloc[:,1:]
y
# Out:
#       Salary
# 0    39343.0
# 1    46205.0
# 2    37731.0
# 3    43525.0
# 4    39891.0
# 5    56642.0
# 6    60150.0
# 7    54445.0
# 8    64445.0
# 9    57189.0
# 10   63218.0
# 11   55794.0
# 12   56957.0
# 13   57081.0
# 14   61111.0
# 15   67938.0
# 16   66029.0
# 17   83088.0
# 18   81363.0
# 19   93940.0
# 20   91738.0
# 21   98273.0
# 22  101302.0
# 23  113812.0
# 24  109431.0
# 25  105582.0
# 26  116969.0
# 27  112635.0
# 28  122391.0
# 29  121872.0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_train,y_train,color = 'red')
plt.plot(x_train,lr.predict(x_train),color="green")
plt.xlabel("Y")
plt.ylabel("S")
# Out:
# Text(0, 0.5, 'S')

# %%
plt.scatter(x_test,y_test,color = 'red')
plt.plot(x_test,lr.predict(x_test),color="green")
plt.xlabel("Y")
plt.ylabel("S")
# Out:
# Text(0, 0.5, 'S')

# %%
df = pd.read_csv("/content/sample_data/combined cycle powerplant.csv")

# %%
df
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9563  15.12  48.92  1011.80  72.93  462.59
# 9564  33.41  77.95  1010.30  59.72  432.90
# 9565  15.99  43.34  1014.20  78.66  465.96
# 9566  17.65  59.87  1018.58  94.65  450.93
# 9567  23.68  51.30  1011.86  71.24  451.67
#
# [9568 rows x 5 columns]

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#          AT      V       AP     RH
# 0      8.34  40.77  1010.84  90.01
# 1     23.64  58.49  1011.40  74.20
# 2     29.74  56.90  1007.15  41.91
# 3     19.07  49.69  1007.22  76.79
# 4     11.80  40.66  1017.13  97.20
# ...     ...    ...      ...    ...
# 9563  15.12  48.92  1011.80  72.93
# 9564  33.41  77.95  1010.30  59.72
# 9565  15.99  43.34  1014.20  78.66
# 9566  17.65  59.87  1018.58  94.65
# 9567  23.68  51.30  1011.86  71.24
#
# [9568 rows x 4 columns]

# %%
y = df.iloc[:,-1:]

# %%
y
# Out:
#           PE
# 0     480.48
# 1     445.75
# 2     438.76
# 3     453.09
# 4     464.43
# ...      ...
# 9563  462.59
# 9564  432.90
# 9565  465.96
# 9566  450.93
# 9567  451.67
#
# [9568 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,y_pred,color="green")
plt.title("actual VS predicted")
plt.xlabel("actual")
plt.ylabel("predicted")
# Out:
# Text(0, 0.5, 'predicted')

# %%
pred_ds=pd.DataFrame()
pred_ds["actual"] = y_test
pred_ds["Predicted"] = y_pred

# %%
pred_ds
# Out:
#       actual   Predicted
# 2513  433.27  435.844874
# 9411  438.16  437.447577
# 8745  458.42  461.252149
# 9085  480.82  476.059882
# 4950  441.41  435.811718
# ...      ...         ...
# 981   480.31  480.039097
# 4694  446.77  453.837232
# 1407  454.66  450.978874
# 535   483.77  483.406809
# 5327  441.51  435.479268
#
# [2871 rows x 2 columns]
